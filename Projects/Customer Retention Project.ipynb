# %% [markdown]
# Introduction:
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %%
#Importing various libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading dataset
data=pd.read_excel('customer_retention_dataset.xlsx')

# %%
#Checking the overview of the data
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %% [markdown]
# We can see that there about 268 rows and 71 columns present in the dataset

# %%
#Checking the shape of the dataset
data.shape
# Out:
# (269, 71)

# %%
#Checking if there are any null values present or not
data.isna().sum()[0:50]
# Out:
# 1Gender of respondent                                                                                                                                                                                                  0
# 2 How old are you?                                                                                                                                                                                                     0
# 3 Which city do you shop online from?                                                                                                                                                                                  0
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  0
# ...

# %%
#Checking if there are any null values present or not
data.isna().sum()[49:72]
# Out:
# Visual appealing web-page layout                                           0
# Wild variety of product on offer                                           0
# Complete, relevant description information of products                     0
# Fast loading website speed of website and application                      0
# Reliability of the website or application                                  0
# Quickness to complete purchase                                             0
# Availability of several payment options                                    0
# Speedy order delivery                                                      0
# Privacy of customers’ information                                          0
# Security of customer financial information                                 0
# Perceived Trustworthiness                                                  0
# Presence of online assistance through multi-channel                        0
# ...

# %%
#checking datatypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %% [markdown]
# In this data only one column has integer data type that is pincode and rest all the columns have string data type that is object.

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
#Checking if there are any duplicates present
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (103, 71)

# %% [markdown]
# By looking at the nu,ber of rows we can that there were duplicates present in the dataset and it has been removed.

# %%
#Checking unique values
data['1Gender of respondent'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['1Gender of respondent'].value_counts()
# Out:
# Female    66
# Male      37
# Name: 1Gender of respondent, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='1Gender of respondent',data=data)
plt.xlabel('Gender')
plt.show()

# %% [markdown]
# By looking at the plot we can say that females are more than male.
# This means that most of the female shopes online compared to male.

# %%
#Checking unique values
data['2 How old are you? '].unique()
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['2 How old are you? '].value_counts()
# Out:
# 21-30 years           32
# 31-40 years           30
# 41-50 yaers           29
# Less than 20 years     6
# 51 years and above     6
# Name: 2 How old are you? , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='2 How old are you? ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# By looking at the plot we can see that the people with age between 21 to 30 years are more in numbers in this data followed by the people with age between 31-40 years and 41-50years.
# Least are from the age between 51 years and above and less than 20 years.
# That means most of the people that shops online are from the age group between 21-30 years followed by 31-40 years and least are from the age group between 51 years and above and less than 20 years.

# %%
#Checking how mnay males and females are from particular age group
data.groupby('1Gender of respondent')['2 How old are you? '].value_counts()
# Out:
# 1Gender of respondent  2 How old are you?
# Female                 21-30 years            25
#                        41-50 yaers            18
#                        31-40 years            16
#                        51 years and above      4
#                        Less than 20 years      3
# Male                   31-40 years            14
#                        41-50 yaers            11
#                        21-30 years             7
#                        Less than 20 years      3
#                        51 years and above      2
# Name: 2 How old are you? , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='2 How old are you? ',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# So by looking at the plot we can say that from age group 21-30years most of the females purchase online compared to male.
# And like from every age group we can notice that number of females purchase online more than number of males.
# So we can say that most of the females who purchase online are from age group 21-30years and for male they are from group 31-40years

# %%
#Checking unique values
data['3 Which city do you shop online from?'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            22
# Greater Noida    17
# Bangalore        17
# Noida            17
# Karnal           11
# Merrut            5
# Ghaziabad         5
# Solan             4
# Gurgaon           3
# Moradabad         1
# Bulandshahr       1
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='3 Which city do you shop online from?',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('City')
plt.show()

# %% [markdown]
# So by looking at the plot we can say that the most of the people are from delhi followed by Greater Noida,Bangalore and Noida. And least are from bulandshahr.
# So that means that most of the orders come from Delhi followed by Greater Noida, Bangalore and Noida..
# Least of the orders come from bulandshahr.

# %%
#Checking how many females and males shopes online from particular city
data.groupby('1Gender of respondent')['3 Which city do you shop online from?'].value_counts()
# Out:
# 1Gender of respondent  3 Which city do you shop online from?
# Female                 Bangalore                                16
#                        Greater Noida                            16
#                        Karnal                                   10
#                        Delhi                                     6
#                        Merrut                                    5
#                        Ghaziabad                                 4
#                        Solan                                     4
#                        Noida                                     3
#                        Gurgaon                                   2
# Male                   Delhi                                    16
#                        Noida                                    14
#                        Bangalore                                 1
#                        Bulandshahr                               1
# ...

# %%
#plotting count plot for visualization
sns.countplot(x='3 Which city do you shop online from?',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('City')
plt.show()

# %% [markdown]
# By looking at the plot we can say that most of the females who shopes online are from Greater Noida and Bnagalore, whereas most of the males who shopes online are from Delhi.
# Least of the females and males who shopes online are from merut and greater noida.

# %%
#Checking unique values
data['4 What is the Pin Code of where you shop online from?'].unique()
# Out:
# array([110009, 110030, 201308, 132001, 530068, 110011, 110018, 173229,
#        110039, 244001, 122018, 201310, 560037, 203207, 250001, 201005,
#        110044, 201306, 560010, 201305, 110042, 132036, 560018, 110008,
#        560002, 201303, 201312, 203202, 560001, 201304, 560003, 110014,
#        560013, 173212, 122009, 201009, 201008, 201001, 203001],
#       dtype=int64)

# %%
#Checking counts of unique values present in the dataset
data['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    13
# 132001     7
# 110044     7
# 201310     6
# 250001     5
# 132036     4
# 560037     4
# 201305     3
# 110008     3
# 201306     3
# 560010     3
# 201312     3
# 110011     3
# 110042     2
# 201303     2
# 560018     2
# 173212     2
# 201304     2
# 560002     2
# 201005     2
# 110014     2
# 122018     2
# 173229     2
# 110018     2
# 530068     2
# 560003     2
# 122009     1
# 201009     1
# 201008     1
# 201001     1
# 560013     1
# 110009     1
# 560001     1
# 203202     1
# 110030     1
# 203207     1
# 244001     1
# 110039     1
# 203001     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
#plotting count plot for visualization
plt.figure(figsize=(10,5))
sns.countplot(x='4 What is the Pin Code of where you shop online from?',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Pincode')
plt.show()

# %% [markdown]
# So we can say that most of the orders comes from area with pincode 201308 and least orders come from the area with pincode 122009,201009,201008,201001,560013,110009,560001,203202,110030,203207,244001,110039 and 203001 having 1 order each.

# %%
#Checking how many males and females shopes more accoring to pincodes
data.groupby('1Gender of respondent')['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 1Gender of respondent  4 What is the Pin Code of where you shop online from?
# Female                 201308                                                   8
#                        132001                                                   6
#                        250001                                                   5
#                        132036                                                   4
#                        560037                                                   4
#                        201306                                                   3
#                        201310                                                   3
#                        201312                                                   3
#                        560010                                                   3
#                        173212                                                   2
# ...

# %%
#plotting count plot for visualization
plt.figure(figsize=(20,5))
sns.countplot(x='4 What is the Pin Code of where you shop online from?',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Pincode')
plt.show()

# %% [markdown]
# So by looking at the count plot we can say that most of the people shops from the pincode 201308 and from that it appears that most of the females shops more from the pincode 201308 and most of the males purchase online from pincode 110044.

# %%
#Checking unique values
data['5 Since How Long You are Shopping Online ?'].unique()
# Out:
# array(['Above 4 years', '3-4 years', '2-3 years', 'Less than 1 year',
#        '1-2 years'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       39
# 2-3 years           23
# Less than 1 year    18
# 3-4 years           16
# 1-2 years            7
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='5 Since How Long You are Shopping Online ?',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('How Long You are Shopping Online')
plt.show()

# %% [markdown]
# As we can see from the plot that most of the people are shopping online from past 4 years and above.
# And least of the people shopping online are from like 1-2 years.

# %%
#Checking from how long males and females are doing online purchase
data.groupby('1Gender of respondent')['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# 1Gender of respondent  5 Since How Long You are Shopping Online ?
# Female                 Above 4 years                                 28
#                        2-3 years                                     14
#                        Less than 1 year                              11
#                        3-4 years                                      8
#                        1-2 years                                      5
# Male                   Above 4 years                                 11
#                        2-3 years                                      9
#                        3-4 years                                      8
#                        Less than 1 year                               7
#                        1-2 years                                      2
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='5 Since How Long You are Shopping Online ?',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('How Long You are Shopping Online')
plt.show()

# %% [markdown]
# So we can see that most of the females as well as males are shopping online from past 4 years and above.

# %%
#Checking unique values
data['6 How many times you have made an online purchase in the past 1 year?'].unique()
# Out:
# array(['31-40 times', '41 times and above', 'Less than 10 times',
#        '11-20 times', '21-30 times', '42 times and above'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    39
# 31-40 times           24
# 41 times and above    22
# 11-20 times           12
# 21-30 times            4
# 42 times and above     2
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Online purchase in the past 1 year')
plt.show()

# %% [markdown]
# In we can see that most of the people have done online purchase i.e less than 10 times a year followed by people who have done online purchase 31-40 times a year and least is 42 times nad above, very few people have online purchase so many times in a year.

# %%
#Checking how many times males and females have done online purchase for a year
data.groupby('1Gender of respondent')['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# 1Gender of respondent  6 How many times you have made an online purchase in the past 1 year?
# Female                 Less than 10 times                                                       23
#                        31-40 times                                                              17
#                        41 times and above                                                       16
#                        11-20 times                                                               9
#                        42 times and above                                                        1
# Male                   Less than 10 times                                                       16
#                        31-40 times                                                               7
#                        41 times and above                                                        6
# ...

# %%
#plotting count plot for visualization
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Online purchase in the past 1 year')
plt.show()

# %% [markdown]
# Most of the females and males have done online purchase less than 10 times in a year and least 42 times and above by both male and females

# %%
#Checking unique values
data[ '7 How do you access the internet while shopping on-line?'].unique()
# Out:
# array(['Dial-up', 'Wi-Fi', 'Mobile Internet', 'Mobile internet'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ '7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    70
# Wi-Fi              21
# Mobile Internet    11
# Dial-up             1
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='7 How do you access the internet while shopping on-line?',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('How do you access the internet while shopping on-line')
plt.show()

# %% [markdown]
# So we can see that most of the people use mobile internet to do shoping online and very less people use dial up to shop online.

# %%
#Checking how many males and females use particular type inteernet access to do online shopping
data.groupby('1Gender of respondent')['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# 1Gender of respondent  7 How do you access the internet while shopping on-line?
# Female                 Mobile internet                                             42
#                        Wi-Fi                                                       18
#                        Mobile Internet                                              6
# Male                   Mobile internet                                             28
#                        Mobile Internet                                              5
#                        Wi-Fi                                                        3
#                        Dial-up                                                      1
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='7 How do you access the internet while shopping on-line?',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('How do you access the internet while shopping on-line')
plt.show()

# %% [markdown]
# In this we can see that most of the females as well as males use mobile internet to purchase online.very few males use dialup and females are not at all using dial up.

# %%
#Checking unique values
data['8 Which device do you use to access the online shopping?'].unique()
# Out:
# array(['Desktop', 'Smartphone', 'Tablet', 'Laptop'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    52
# Laptop        32
# Desktop       13
# Tablet         6
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='8 Which device do you use to access the online shopping?',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Which device do you use to access the online shopping')
plt.show()

# %% [markdown]
# Most of the people use smartphone to purchase online and very less people use tablet.

# %%
#Checking how many males and females use particular device to purchase online
data.groupby('1Gender of respondent')['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# 1Gender of respondent  8 Which device do you use to access the online shopping?
# Female                 Smartphone                                                  37
#                        Laptop                                                      21
#                        Desktop                                                      8
# Male                   Smartphone                                                  15
#                        Laptop                                                      11
#                        Tablet                                                       6
#                        Desktop                                                      5
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='8 Which device do you use to access the online shopping?',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Which device do you use to access the online shopping')
plt.show()

# %% [markdown]
# So in this we can see that most of the males and females use smartphone to purchase online and
# very less males as well as females use desktop to purchase online

# %%
#Checking unique values
data['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].unique()
# Out:
# array(['Window/windows Mobile', 'IOS/Mac', 'Android'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    46
# Android                  30
# IOS/Mac                  27
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='10 What is the operating system (OS) of your device?\t\t\t\t                                          ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('What is the operating system (OS) of your device?\t\t\t\t                                          ')
plt.show()

# %% [markdown]
# It seems that most of people use wondows mobile as as compared to android and ios.

# %%
#Checking how many males and females use particular device(os) to purchase online
data.groupby('1Gender of respondent')['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# 1Gender of respondent  10 What is the operating system (OS) of your device?\t\t\t\t
# Female                 Window/windows Mobile                                                                                     30
#                        IOS/Mac                                                                                                   19
#                        Android                                                                                                   17
# Male                   Window/windows Mobile                                                                                     16
#                        Android                                                                                                   13
#                        IOS/Mac                                                                                                    8
# ...

# %%
#plotting count plot for visualization
sns.countplot(x='10 What is the operating system (OS) of your device?\t\t\t\t                                          ',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('What is the operating system (OS) of your device?\t\t\t\t                                          ')
plt.show()

# %% [markdown]
# So most of the males as well as females use winddows mobile

# %%
#Checking unique values
data[ '11 What browser do you run on your device to access the website?\t\t\t                                                          '].unique()
# Out:
# array(['Google chrome', 'Safari', 'Opera', 'Mozilla Firefox'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      80
# Safari             19
# Opera               2
# Mozilla Firefox     2
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='11 What browser do you run on your device to access the website?\t\t\t                                                          ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('What browser do you run on your device to access the website?\t\t\t                                                          ')
plt.show()

# %% [markdown]
# Most of the people use google chrome browser to acces the website.

# %%
#Checking how many males and females use particular type of browser while accessing the website 
data.groupby('1Gender of respondent')[['11 What browser do you run on your device to access the website?\t\t\t                                                          ']].value_counts()
# Out:
# 1Gender of respondent  11 What browser do you run on your device to access the website?\t\t\t
# Female                 Google chrome                                                                                                                       51
#                        Safari                                                                                                                              14
#                        Opera                                                                                                                                1
# Male                   Google chrome                                                                                                                       29
#                        Safari                                                                                                                               5
# ...

# %%
#plotting count plot for visualization
sns.countplot(x='11 What browser do you run on your device to access the website?\t\t\t                                                          ',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('What browser do you run on your device to access the website?\t\t\t                                                          ')
plt.show()

# %% [markdown]
# Most of the females as well as males use google chrome browser while accessing the website.

# %%
#Checking unique values
data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].unique()
# Out:
# array(['6-10 mins', 'more than 15 mins', '11-15 mins', '1-5 mins',
#        'Less than 1 min'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    48
# 6-10 mins            31
# 11-15 mins           15
# 1-5 mins              5
# Less than 1 min       4
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('How much time do you explore the e- retail store before making a purchase decision?                                                                   ')
plt.show()

# %% [markdown]
# By looking at the plot we can say like most of the people spends more than 15 mins to explore the e-retail store before making any purchase

# %%
#Checking how much time does males and females spend to explore the e-retail store before making any purchase
data.groupby('1Gender of respondent')['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# 1Gender of respondent  14 How much time do you explore the e- retail store before making a purchase decision?
# Female                 more than 15 mins                                                                                                                                            33
#                        6-10 mins                                                                                                                                                    15
#                        11-15 mins                                                                                                                                                   12
#                        1-5 mins                                                                                                                                                      3
# ...

# %%
#plotting count plot for visualization
sns.countplot(x='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('How much time do you explore the e- retail store before making a purchase decision?                                                                   ')
plt.show()

# %% [markdown]
# So we can say that most of the females spend more than 15 minutes to explore the e- retail store before making a purchase decision and most of the males spends about 6-10mins before making a purchase decision

# %%
#Checking unique values
data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].unique()
# Out:
# array(['E-wallets (Paytm, Freecharge etc.)', 'Credit/Debit cards',
#        'Cash on delivery (CoD)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    59
# Cash on delivery (CoD)                25
# E-wallets (Paytm, Freecharge etc.)    19
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ')
plt.show()

# %% [markdown]
# Most of the people prefer to pay by credit or debit cards

# %%
#Checking what type of payment option does males and females prefer
data.groupby('1Gender of respondent')['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# 1Gender of respondent  15 What is your preferred payment Option?\t\t\t\t\t
# Female                 Credit/Debit cards                                                                                                                                                                    36
#                        Cash on delivery (CoD)                                                                                                                                                                18
#                        E-wallets (Paytm, Freecharge etc.)                                                                                                                                                    12
# Male                   Credit/Debit cards                                                                                                                                                                    23
# ...

# %%
#plotting count plot for visualization
sns.countplot(x='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',hue='1Gender of respondent',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ')
plt.show()

# %% [markdown]
# So its clear that most of the males and females prefer to pay by using credit/debit cards

# %%
#Checking unique values
data['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].unique()
# Out:
# array(['Amazon.in, Paytm.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com, Paytm.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                12
# Amazon.in, Flipkart.com                                         12
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Flipkart.com, Snapdeal.com                            8
# Amazon.in, Paytm.com                                             5
# Amazon.in                                                        4
# Amazon.in, Flipkart.com, Paytm.com                               2
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Most of the people have purchased online from every online retailer that is amazone,flipkart,paytm,myntra and snapdeal.

# %%
#Checking unique values
data[ 'Easy to use website or application'].unique()
# Out:
# array(['Paytm.com', 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in', 'Amazon.in, Paytm.com', 'Flipkart.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ 'Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    28
# Amazon.in, Flipkart.com                                         18
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               16
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                10
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in                                                        8
# Amazon.in, Flipkart.com, Myntra.com                              6
# Paytm.com                                                        5
# Amazon.in, Paytm.com                                             2
# Flipkart.com                                                     2
# Name: Easy to use website or application, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Easy to use website or application',data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# By looking at the plot we get a clear idea that most of the people like to use website over application

# %%
#Checking unique values
data['33 Return and replacement policy of the e-tailer is important for purchase decision'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'Agree (4)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    76
# Agree (4)             20
# Dis-agree (2)          7
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '33 Return and replacement policy of the e-tailer is important for purchase decision',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Return and replacement policy of the e-tailer is important for purchase decision')
plt.show()

# %% [markdown]
# Most of the people strongly agree to the return and replacement policy is important for purchase decision

# %%
#Checking unique values
data['Reliability of the website or application'].unique()
# Out:
# array(['Paytm.com', 'Myntra.com', 'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            20
# Amazon.in, Flipkart.com                              18
# Amazon.in, Paytm.com, Myntra.com                     16
# Amazon.in, Flipkart.com, Paytm.com                   16
# Amazon.in, Flipkart.com, Snapdeal.com                 7
# Myntra.com                                            6
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com      6
# Paytm.com                                             5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     5
# Flipkart.com                                          4
# Name: Reliability of the website or application, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Reliability of the website or application',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Reliability of the website or application')
plt.show()

# %% [markdown]
# So we can see that most of the people think or say that Amazon website is the most reliable one.

# %%
#Checking unique values
data['Complete, relevant description information of products'].unique()
# Out:
# array(['Snapdeal.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in, Paytm.com, Myntra.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Flipkart.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Flipkart.com'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         39
# Amazon.in                                                       12
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Paytm.com, Myntra.com                                 8
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     8
# Amazon.in, Flipkart.com, Myntra.com                              6
# Snapdeal.com                                                     5
# Flipkart.com, Snapdeal.com                                       5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Snapdeal.com                            2
# Flipkart.com                                                     2
# Name: Complete, relevant description information of products, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Complete, relevant description information of products',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Complete, relevant description information of products')
plt.show()

# %% [markdown]
# Most of the people says that Amazone and flipkart wensite provides with complete,relevant description and information of the products.

# %%
#Checking unique values
data['Fast loading website speed of website and application'].unique()
# Out:
# array(['Snapdeal.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in, Paytm.com', 'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Amazon.in',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in, Paytm.com                                            19
# Amazon.in                                                       18
# Amazon.in, Flipkart.com, Myntra.com                             11
# Amazon.in, Flipkart.com, Snapdeal.com                           11
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    11
# Amazon.in, Flipkart.com                                         11
# Amazon.in, Flipkart.com, Paytm.com                              10
# Snapdeal.com                                                     5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Flipkart.com                                                     2
# Name: Fast loading website speed of website and application, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Fast loading website speed of website and application',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Fast loading website speed of website and application')
plt.show()

# %% [markdown]
# By looking at the plot we can say that amazone and paytm are the fast loading websites compared to several other websites

# %%
#Checking unique values
data['Quickness to complete purchase'].unique()
# Out:
# array(['Paytm.com', 'Amazon.com, Flipkart.com, Myntra.com',
#        'Amazon.com, Paytm.com, Myntra.com',
#        'Amazon.com, Flipkart.com, Paytm.com',
#        'Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal',
#        'Amazon.com', 'Flipkart.com, Myntra.com, Snapdeal',
#        'Amazon.com, Flipkart.com', 'Flipkart.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   22
# Amazon.com, Flipkart.com, Paytm.com                          21
# Amazon.com, Flipkart.com                                     13
# Paytm.com                                                    11
# Amazon.com, Flipkart.com, Myntra.com                         11
# Amazon.com, Paytm.com, Myntra.com                             8
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal     8
# Flipkart.com, Myntra.com, Snapdeal                            5
# Flipkart.com                                                  4
# Name: Quickness to complete purchase, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Quickness to complete purchase',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Quickness to complete purchase')
plt.show()

# %% [markdown]
# Most of the people have ticked marked or voted that Amazone is the quickest to complete purchase.As most of the people does not like to waste time. They want everything straightforward unlike some of the online retailsers they have so much of steps and formality that some people gets irritate and than drops of the idea of buying from that online retailer.

# %%
#Checking unique values
data[ 'Speedy order delivery '].unique()
# Out:
# array(['Amazon.in', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com',
#        'Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com, Myntra.com', 'Flipkart.com'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 43
# Amazon.in, Flipkart.com                   30
# Amazon.in, Flipkart.com, Snapdeal.com     16
# Flipkart.com, Myntra.com, Snapdeal.com     5
# Amazon.in, Flipkart.com, Myntra.com        5
# Flipkart.com                               4
# Name: Speedy order delivery , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x=  'Speedy order delivery ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Speedy order delivery ')
plt.show()

# %% [markdown]
# It seems that Amazone makes speedy order delivery which is very important for the people

# %%
#Checking unique values
data['Longer delivery period'].unique()
# Out:
# array(['Paytm.com', 'Snapdeal.com', 'Flipkart.com', 'Amazon.in',
#        'Paytm.com, Snapdeal.com', 'Myntra.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  32
# Snapdeal.com               24
# Flipkart.com               18
# Amazon.in                  11
# Paytm.com, Snapdeal.com    10
# Myntra.com                  8
# Name: Longer delivery period, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='Longer delivery period',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Longer delivery period')
plt.show()

# %% [markdown]
# Most of the people think or says that paytm takes a long time to deliver the material which is purchased online.

# %%
#Checking unique values
data['Website is as efficient as before'].unique()
# Out:
# array(['Amazon.in', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Paytm.com', 'Snapdeal.com',
#        'Myntra.com, Snapdeal.com', 'Flipkart.com', 'Amazon.in, Paytm.com'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             35
# Flipkart.com                          17
# Amazon.in, Flipkart.com               15
# Amazon.in, Flipkart.com, Paytm.com    11
# Paytm.com                              8
# Amazon.in, Paytm.com                   7
# Snapdeal.com                           5
# Myntra.com, Snapdeal.com               5
# Name: Website is as efficient as before, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='Website is as efficient as before',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Website is as efficient as before')
plt.show()

# %% [markdown]
# So by looking at the plot we can say Amazone website is as efficient as before.

# %%
#Checking unique values
data['22 Ease of navigation in website'].unique()
# Out:
# array(['Agree (4)', 'Strongly agree (5)', 'Strongly disagree (1)',
#        'Dis-agree (2)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       51
# Agree (4)                42
# Strongly disagree (1)     8
# Dis-agree (2)             2
# Name: 22 Ease of navigation in website, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='22 Ease of navigation in website',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( ' Ease of navigation in website')
plt.show()

# %% [markdown]
# Most of the people strongly agree that there should be ease of navigation in the website

# %%
#Checking unique values
data[ '23 Loading and processing speed'].unique()
# Out:
# array(['Strongly disagree (1)', 'Strongly agree (5)', 'Agree (4)',
#        'Dis-agree (2)', 'Indifferent (3)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ '23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       45
# Agree (4)                41
# Dis-agree (2)             8
# Strongly disagree (1)     5
# Indifferent (3)           4
# Name: 23 Loading and processing speed, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '23 Loading and processing speed',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Loading and processing speed')
plt.show()

# %% [markdown]
# Most of the people strongly agree that the loading and the processing speed should be good

# %%
#Checking unique values
data[ '24 User friendly Interface of the website'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'Agree (4)',
#        'Strongly disagree (1)', 'Indifferent (3)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ '24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       72
# Agree (4)                16
# Strongly disagree (1)     8
# Dis-agree (2)             5
# Indifferent (3)           2
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '24 User friendly Interface of the website',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'User friendly Interface of the website')
plt.show()

# %% [markdown]
# Most of the people strongly agree that the interface of the website should be user friendly

# %%
#Checking unique values
data[ '25 Convenient Payment methods'].unique()
# Out:
# array(['Dis-agree (2)', 'Strongly agree (5)', 'Agree (4)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    60
# Agree (4)             30
# Dis-agree (2)         13
# Name: 25 Convenient Payment methods, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '25 Convenient Payment methods',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Convenient Payment methods')
plt.show()

# %% [markdown]
# Most of the people strongly agree that there should be convinient payment methods

# %%
#Checking unique values
data[ '39 Offering a wide variety of listed product in several category'].unique()
# Out:
# array(['indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Dis-agree (2)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    42
# Agree (4)             39
# indifferent (3)       20
# Dis-agree (2)          2
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '39 Offering a wide variety of listed product in several category',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Offering a wide variety of listed product in several category')
plt.show()

# %% [markdown]
# Most of the people strongly agree that there should be wide variety of listed product in several categories

# %%
#Checking unique values
data['Wild variety of product on offer'].unique()
# Out:
# array(['Flipkart.com', 'Flipkart.com, Myntra.com',
#        'Amazon.in, Myntra.com', 'Amazon.in, Flipkart.com', 'Myntra.com',
#        'Amazon.in, Flipkart.com, Paytm.com', 'Amazon.in',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com', 'Paytm.com'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              50
# Amazon.in                                            13
# Amazon.in, Myntra.com                                 8
# Myntra.com                                            8
# Flipkart.com, Myntra.com                              6
# Amazon.in, Flipkart.com, Paytm.com                    6
# Flipkart.com                                          5
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     5
# Paytm.com                                             2
# Name: Wild variety of product on offer, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Wild variety of product on offer',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Wild variety of product on offer')
plt.show()

# %% [markdown]
# So it seems that amazon and filpkart website have more wide variety  of products on offer compared to other online retailers

# %%
#Checking unique values
data['Presence of online assistance through multi-channel'].unique()
# Out:
# array(['Paytm.com', 'Amazon.in, Flipkart.com, Myntra.com', 'Myntra.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal',
#        'Amazon.in, Myntra.com', 'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in', 'Amazon.in, Flipkart.com', 'Amazon.in, Snapdeal',
#        'Flipkart.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    24
# Amazon.in                                        21
# Amazon.in, Flipkart.com                          15
# Myntra.com                                        8
# Amazon.in, Myntra.com                             8
# Amazon.in, Snapdeal                               8
# Amazon.in, Flipkart.com, Myntra.com               6
# Amazon.in, Flipkart.com, Paytm.com                6
# Paytm.com                                         5
# Flipkart.com                                      2
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Presence of online assistance through multi-channel',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Presence of online assistance through multi-channel')
plt.show()

# %% [markdown]
# So by looking at the plot we can see that Amazon,flipkart,myntra and snapdeal have more presence of online assistance through multi-channel as compared to other online retailers

# %%
#Checking unique values
data[ 'Late declaration of price (promotion, sales period)'].unique()
# Out:
# array(['Flipkart.com', 'snapdeal.com', 'Myntra.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Amazon.in', 'Paytm.com, snapdeal.com',
#        'Amazon.in, Flipkart.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ 'Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 30
# Paytm.com                  24
# Flipkart.com               14
# snapdeal.com               14
# Amazon.in                  11
# Amazon.in, Paytm.com        6
# Paytm.com, snapdeal.com     2
# Amazon.in, Flipkart.com     2
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x=  'Late declaration of price (promotion, sales period)',data=data)
plt.xticks(rotation='vertical')
plt.xlabel(  'Late declaration of price (promotion, sales period)')
plt.show()

# %% [markdown]
# It seems that most of the people agree that myntra is always late to declare its prices(promotion and sales period).
# And fery few people agree that amazon and flipkart is always late to declare its prices(promotion and sales period).

# %%
#Checking unique values
data[ 'Longer page loading time (promotion, sales period)'].unique()
# Out:
# array(['Flipkart.com', 'Snapdeal.com', 'Myntra.com', 'Paytm.com',
#        'Amazon.in, Paytm.com', 'Amazon.in, Flipkart.com',
#        'Amazon.in, Snapdeal.com', 'Flipkart.com, Snapdeal.com',
#        'Paytm.com, Snapdeal.com', 'Amazon.in',
#        'Amazon.in, Paytm.com, Myntra.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ 'Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Paytm.com                           27
# Myntra.com                          22
# Flipkart.com                        11
# Snapdeal.com                         8
# Amazon.in, Flipkart.com              8
# Amazon.in, Paytm.com                 6
# Amazon.in, Snapdeal.com              5
# Flipkart.com, Snapdeal.com           5
# Paytm.com, Snapdeal.com              5
# Amazon.in                            4
# Amazon.in, Paytm.com, Myntra.com     2
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x=  'Longer page loading time (promotion, sales period)',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( 'Longer page loading time (promotion, sales period)')
plt.show()

# %% [markdown]
# Most of the people agree that paytm takes more time to load the page.

# %%
#Checking unique values
data[ '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].unique()
# Out:
# array(['Lack of trust', 'Promo code not applicable',
#        'Better alternative offer', 'Change in price',
#        'No preferred mode of payment'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        49
# Promo code not applicable       21
# Change in price                 15
# Lack of trust                   13
# No preferred mode of payment     5
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x=  '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ')
plt.show()

# %% [markdown]
# So we can see that most of the poeple abandon the bag or shopping kart beacause they get better alternative offer on the same product from other online reatailer.

# %%
#Checking unique values
data[ 'Limited mode of payment on most products (promotion, sales period)'].unique()
# Out:
# array(['Amazon.in', 'Snapdeal.com', 'Paytm.com', 'Amazon.in, Paytm.com',
#        'Flipkart.com', 'Amazon.in, Flipkart.com',
#        'Paytm.com, Snapdeal.com', 'Myntra.com, Snapdeal.com'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                33
# Amazon.in                   22
# Amazon.in, Flipkart.com     13
# Paytm.com                   11
# Flipkart.com                11
# Amazon.in, Paytm.com         6
# Paytm.com, Snapdeal.com      5
# Myntra.com, Snapdeal.com     2
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Limited mode of payment on most products (promotion, sales period)',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Limited mode of payment on most products (promotion, sales period)')
plt.show()

# %% [markdown]
# Most of the people agree that the snapdeal has the limited mode of payment on most products

# %%
#Checking unique values
data[ 'Frequent disruption when moving from one page to another'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Paytm.com', 'Amazon.in, Flipkart.com',
#        'Snapdeal.com', 'Flipkart.com', 'Myntra.com, Snapdeal.com',
#        'Flipkart.com, Snapdeal.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Myntra.com                    21
# Amazon.in                     19
# Snapdeal.com                  18
# Paytm.com                     14
# Amazon.in, Flipkart.com       11
# Flipkart.com                  10
# Myntra.com, Snapdeal.com       5
# Flipkart.com, Snapdeal.com     5
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= 'Frequent disruption when moving from one page to another',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Frequent disruption when moving from one page to another')
plt.show()

# %% [markdown]
# Most of the people agree that in myntra website  there are problems or disturbances when moving from one page to another

# %%
#Checking unique values
data[ '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].unique()
# Out:
# array(['Disagree (2)', 'Strongly agree (5)', 'Agree (4)',
#        'indifferent  (3)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    52
# Agree (4)             34
# Disagree (2)          13
# indifferent  (3)       4
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Trust that the online retail store will fulfill its part of the transaction at the stipulated time')
plt.show()

# %% [markdown]
# People strongly agree about the trust that the online retail store will fulfill its part of the transaction at the stipulated time

# %%
#Checking unique values
data[ '30 Online shopping gives monetary benefit and discounts'].unique()
# Out:
# array(['indifferent (3)', 'Strongly agree (5)', 'Agree (4)',
#        'Strongly disagree (1)', 'Dis-agree (2)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       41
# Agree (4)                33
# indifferent (3)          16
# Strongly disagree (1)     8
# Dis-agree (2)             5
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x= '30 Online shopping gives monetary benefit and discounts',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Online shopping gives monetary benefit and discounts')
plt.show()

# %% [markdown]
# Most of the people strongly agree that online shopping gives them monitary benefits and discounts

# %%
#Checking unique values
data[  '38 User satisfaction cannot exist without trust'].unique()
# Out:
# array(['Strongly agree (5)', 'Agree (4)', 'Strongly disagree (1)',
#        'Dis-agree (2)', 'indifferent (3)'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data[ '38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       47
# Agree (4)                44
# Strongly disagree (1)     8
# Dis-agree (2)             2
# indifferent (3)           2
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x=  '38 User satisfaction cannot exist without trust',data=data)
plt.xticks(rotation='vertical')
plt.xlabel( ' User satisfaction cannot exist without trust')
plt.show()

# %% [markdown]
# Most of the people strongly agree that trust plays an important role in user satisfaction.

# %%
#Checking unique values
data['Privacy of customers’ information'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Amazon.in, Flipkart.com, Myntra.com',
#        'Amazon.in, Paytm.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Paytm.com', 'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Flipkart.com'],
#       dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       24
# Amazon.in, Flipkart.com                                         19
# Amazon.in, Flipkart.com, Myntra.com                             11
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    11
# Amazon.in, Paytm.com                                             8
# Paytm.com                                                        8
# Myntra.com                                                       6
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Paytm.com                               5
# Flipkart.com                                                     4
# Amazon.in, Flipkart.com, Snapdeal.com                            2
# Name: Privacy of customers’ information, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='Privacy of customers’ information',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Privacy of customers’ information')
plt.show()

# %% [markdown]
# privacy also plays an important role as people does want others to know about there personal things.So most of the poeple think the amzone keeps the customer information very safe.

# %%
#Checking unique values
data['Security of customer financial information'].unique()
# Out:
# array(['Amazon.in', 'Myntra.com', 'Amazon.in, Paytm.com, Myntra.com',
#        'Amazon.in, Flipkart.com, Snapdeal.com', 'Paytm.com',
#        'Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com',
#        'Flipkart.com',
#        'Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com',
#        'Amazon.in, Flipkart.com', 'Amazon.in, Flipkart.com, Paytm.com',
#        'Amazon.in, Snapdeal.com'], dtype=object)

# %%
#Checking counts of unique values present in the dataset
data['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       16
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    16
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Snapdeal.com                           11
# Amazon.in, Flipkart.com                                         10
# Amazon.in, Paytm.com, Myntra.com                                 8
# Paytm.com                                                        8
# Myntra.com                                                       6
# Amazon.in, Snapdeal.com                                          6
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                5
# Amazon.in, Flipkart.com, Paytm.com                               5
# Name: Security of customer financial information, dtype: int64

# %%
#plotting count plot for visualization
sns.countplot(x='Security of customer financial information',data=data)
plt.xticks(rotation='vertical')
plt.xlabel('Security of customer financial information')
plt.show()

# %% [markdown]
# Again the customer financial information is a thing that should be leaked, its there should be a heavy a security for that, so most of the poeple think that Amazon keeps the finacial information of the customers very safe.
